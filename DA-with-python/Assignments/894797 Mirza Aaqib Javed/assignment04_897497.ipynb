# %% [markdown]
# craete a dictionary called studentswith keys : name,age,cource,city.Print each value

# %%
student = {
    
    "name" : "aaqib",
    "age"  : "32 years",
 "cource"  : " Data Analysit",
 "city"    : "Faisalabad"





}

print(f"name of student is {student['name']} his/her age is {student['age']}, he/she lives in {student['city']} and his cource in which he/she studies in {student['cource']} ")
# Out:
# name of student is aaqib his/her age is 32 years, he/she lives in Faisalabad and his cource in which he/she studies in  Data Analysit

# %% [markdown]
# Updating and adiing dictionaries

# %%
car = {
    
    "brand":"Toyota",
    "model":"Cororlla",
    "year": 2018
    
    }
brand = input("enter the value of brand of car which you want to replace")
try:
    int(brand)
    print("enter string for brand")
        
    
except:
    car["brand"] = brand
        
model = input("enter the value of model of car which you want to replace")
try:
    int(model)
    print("enter string for brand")
         
except:
    car["model"] = model
        
car["year"] = input("enter the year of car built ")        
try:
        
    car["year"] = int(car["year"])
except:
    print("enter the correct value for model in string")

print(car["brand"])
print(car["model"])
print(car["year"])
# Out:
# honda
# city
# 2025

# %% [markdown]
# loop through distionary

# %%
person = {
    
     "name" : "aaqib",
        "age"  : "32 years",
     "cource"  : " Data Analysit",
     "city"    : "Faisalabad"
    
    
    
}

for key in person.keys():
    
    print(key)

for value in person.values():
    print(value)
# Out:
# name
# age
# cource
# city
# aaqib
# 32 years
#  Data Analysit
# Faisalabad

# %% [markdown]
# count frequency

# %%
numbers = [ 1,2,2,3,3,3,4,4,4,4]
frequency = {}
for i in numbers:
    if i in frequency:
        frequency[i] += 1
    else:
        frequency[i] = 1

print(frequency)
# Out:
# {1: 1, 2: 2, 3: 3, 4: 4}

# %% [markdown]
# word counter

# %%
string = input("Enter the string: ")
words = string.split() 
frequency = {}

for word in words:
    if word in frequency:
        frequency[word] += 1
    else:
        frequency[word] = 1

print(frequency)
# Out:
# {'my': 1, 'name': 1, 'is': 1, 'aaqib': 1}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
marks ={
    
    "math": 80,
    "english": 70,
    "physics": 90
    
}
total = 0
for value in marks.values():
    total += value
print(f"average is equal to {total/3}")
print(f" total marks is equal to {total}")
# Out:
# average is equal to 80.0
#  total marks is equal to 240

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
students = {
    
    "ali": 85,
    "sara":92,
    "ahmed":78,
    "zara": 95
    
}
my_list = list(students.values())




print(my_list)

max_val = my_list[0]


for num in my_list:
    if num > max_val:
        max_val = num

print("biggest number is:", max_val)
# Out:
# [85, 92, 78, 95]
# biggest number is: 95

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
dict1 = {'a': 1, 'b': 2}
dict2 = {'c': 3, 'd': 4}

dict1.update(dict2)
print(dict1)
# Output: {'a': 1, 'b': 3, 'c': 4}
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}
