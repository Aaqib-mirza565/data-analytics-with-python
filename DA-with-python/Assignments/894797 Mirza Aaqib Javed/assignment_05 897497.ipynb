# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# using loop entering elements
list = []
n = 1
while n <= 8:
    list.append(n)
    n += 1
print(list)

# printing numbers
total = 0
for i in list:
    print(i)
    total += i 
    
    print("number is ", i, "is this number even ",i % 2 == 0)

print("Total of  number is =",total)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]
# 1
# number is  1 is this number even  False
# 2
# number is  2 is this number even  True
# 3
# number is  3 is this number even  False
# 4
# number is  4 is this number even  True
# 5
# number is  5 is this number even  False
# 6
# number is  6 is this number even  True
# 7
# number is  7 is this number even  False
# 8
# number is  8 is this number even  True
# Total of  number is = 36

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
students = {
    "name":"",
    "age":"",
    "course":"",
    "marks": []
    
}

for key in students:
    if key != "marks":
        value = input(f"Enter the value  for {key}")
        students.update({key: value})

no_of_subjects = int(input("Enter the no of subjects "))
for n in range(1,no_of_subjects + 1 ):
    
            
    val = int(input(f"Enter the marks for subject {n}"))
    students["marks"].append(val)
            
print(students)

for key, value in students.items():
    print(f"Key: {key} -> Value: {value}")
average = 0
total = 0    
for key in students:
    if key == "marks":
        x = students.get("marks")
        for i in x:
            total += i
            
        average = total / len(x)    
         
print("average of marks is ",average)            
    
for key in students:
    if key == "marks":
        x = students.get("marks")
        for i in x:
            
            if i >= 50:
                print(f" Student having marks {i} is pass ")
            else:
                print(f"student  having marks {i} is fail")
# Out:
# {'name': 'aaqib', 'age': '32 years', 'course': 'dara analysit', 'marks': [56, 96, 23]}
# Key: name -> Value: aaqib
# Key: age -> Value: 32 years
# Key: course -> Value: dara analysit
# Key: marks -> Value: [56, 96, 23]
# average of marks is  58.333333333333336
#  Student having marks 56 is pass
#  Student having marks 96 is pass
# student is fail

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
employees = []
employes_dic = {
    
}

emplyee_name = "name"
emplyee_sallery = 0
emplyee_department = "department"
while True:
    try:
        emplyee_name = input("Enter the name of employee want to lsit in" )
        emplyee_name = str(emplyee_name)
    except:
        print("enter the name is string not in other format")    
    if emplyee_name == "":
        break
    
    

    try:
        emplyee_sallery = input(f"Enter the sallery of {emplyee_name} " )
        emplyee_sallery = int(emplyee_sallery)
    except :
        print("Enter the integers for sallery")
    
    if emplyee_sallery == "":
        break
    
    
    try:
        
        emplyee_department = input(f"Enter the department of {emplyee_name} of employee " )
        emplyee_department = str(emplyee_department)
    except:
        print("enter the name is string not in other format")    
    if emplyee_department == "":
        break
    employees.append([emplyee_name,emplyee_sallery,emplyee_department])
    




for index, employees in enumerate(employees):
    emp_id = f"EMP-{index + 1}"
    
    
    employes_dic[emp_id] = {
        "name": employees[0],
        "salary": employees[1],
        "department": employees[2]
    }

for i in employes_dic:
    print(employes_dic.get(i))
    
highest_salary = 0
highest_emp_id = ""

for emp_id in employes_dic:
    
    current_sallery = employes_dic[emp_id]["salary"]
    
    if current_sallery > highest_salary:
        highest_salary = current_sallery
        highest_emp_id = emp_id


print("\nHighest Salary Employee Details:")
print("ID:", highest_emp_id)
print("Name:", employes_dic[highest_emp_id]["name"])
print("Salary:", employes_dic[highest_emp_id]["salary"])
print("Department:", employes_dic[highest_emp_id]["department"])

total = 0

for emp_id in employes_dic:
    sallery = employes_dic[emp_id]["salary"]
    total += sallery

print("total expence of salleries ", total)
# Out:
# {'name': 'aaqib', 'salary': 56000, 'department': 'teacher'}
# {'name': 'saqib', 'salary': 65000, 'department': 'IT'}
# {'name': 'jhon', 'salary': 100000, 'department': 'CEO'}
#
# Highest Salary Employee Details:
# ID: EMP-3
# Name: jhon
# Salary: 100000
# Department: CEO
# total expence of salleries  221000

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for i in range(1,6):
    
    for j in range(1,6):
        print(i * j, end = " ") 

    print()
# Out:
# 1 2 3 4 5
# 2 4 6 8 10
# 3 6 9 12 15
# 4 8 12 16 20
# 5 10 15 20 25

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sentence = input("Enter a sentence: ")
words = sentence.split()
word_counts = {}

for word in words:
    word = word.lower()
    if word in word_counts:
        word_counts[word] += 1
    else:
        word_counts[word] = 1

for word, count in word_counts.items():
    print(f"{word}: {count}")
# Out:
# my: 1
# name: 1
# is: 1
# aaqib: 1
# mirza: 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
numbers = []

while True:
    num = int(input("Enter a number (-1 to stop): "))
    if num == -1:
        break
    numbers.append(num)

if numbers:
    print("Complete list:", numbers)
    print("Largest number:", max(numbers))
    print("Smallest number:", min(numbers))
