# %% [markdown]
# # Part -2 Python Basics (Conditional Statements)

# %% [markdown]
# 1) A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
# Ask user for their salary and year of service and print the net bonus amount.

# %%
#Type your code here
amount = int(input("Enter the salary of employee"))
year_of_service = int(input("Enter the year of service"))

if year_of_service > 5:
    
    bonus = amount*(5 / 100)
    
    amount = amount + bonus
    
    print(f"conguratulations! you got a bonus : {bonus} and your current sallery is { amount}")

else:
    
    print("you are ot eligible yet")
# Out:
# conguratulations! you got a bonus : 75.0 and your current sallery is 1575.0

# %% [markdown]
# 2) Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible

# %%
age = int(input("enter the age of a votter "))
if 17 < age >17:
    print(f" you are eligible to vote")
else:
    print(f"you are not eligible to cast vote")
# Out:
#  you are eligible to vote

# %% [markdown]
# 3) Write a program to check whether a number entered by user is even or odd.

# %%
number = int(input("enter the number "))
if (number%2) == 0:
    print(f" you entered an odd number { number}")
else:
    print(f" you entered an even number { number}")
# Out:
#  you entered an even number 3

# %% [markdown]
# 4) Write a program to check whether a number is divisible by 7 or not.
# Show Answer

# %%
number = int(input("enter the number "))
if (number% 7) == 0:
    
     
    print(f"  { number} is divisible by 7  ")

else:
    print(f" { number} is not divisible by 7  ")
# Out:
#  32 is not divisible by 7

# %% [markdown]
# 5) Write a program to display
# "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
number = int(input("enter the number "))
if (number% 5) == 0:
    
     
    print(f"Hello ")

else:
    print(f" Bye ")
# Out:
#  Bye

# %% [markdown]
# 7) Write a program to display the last digit of a number.

# %%
number = input("enter the number whose digit you want to get")

digit = list(number)
print("Last digit of eneterd ",number ,"is", digit[-1])
# Out:
# Last digit of eneterd  78456238742 is 2

# %% [markdown]
# 9) Take values of length and breadth of a rectangle from user and print if it is square or rectangle.

# %%
length = int(input(" enter the first dimension of shape"))
width = int(input(" enter the second dimension of shape"))
if length == width:
    
    print(f" your entered dimensions are making square ")
else:
    print(f" your entered dimensions are making rectangle ")
# Out:
#  your entered dimensions are making rectangle

# %% [markdown]
# 10) Take two int values from user and print greatest among them.

# %%
int_1 = int(input(" enter the first integer"))
int_2 = int(input(" enter the second integer"))
if int_1 > int_2:
    
    print(f" your entered dimensions are making square ")
else:
    print(f" your entered dimensions are making rectangle ")

# %% [markdown]
# 11) A shop will give discount of 10% if the cost of purchased quantity is more than 1000.
# Ask user for quantity
# Suppose, one unit will cost 100.
# Judge and print total cost for user.

# %%
def purchase_amount():
    n = 1
    goods = []
    print(f"enter the goods you picked to purchase ")
    while n > 0:
        good = input(f"enter good no {n}").strip().title()
        try:
            float(good)  
            print("please enter a proper good name (numbers are not allowed)")
            continue     
        except ValueError:
            if len(good) == 0:
                print("good name cannot be empty")
                continue 
        goods.append(good)
        n = n + 1    
        x = input("if your cart is filled enter 'STOP' or enter 'CONTINUE' to keep shoping ").lower()
        if x == "stop":
            break
    print(goods)  
    if len(goods) <= 10:
        bill = len(goods) * 100
        print(f"your bill without discount is {bill}")
    elif len(goods) > 10:
        bill = len(goods) * 100
        discout = bill * (10/100)
        print(f"your bill without discount is {bill} with discount {bill - discout}")
    else:
        print("shop someting first then come ")    
            
          
purchase_amount()
# Out:
# enter the goods you picked to purchase
# ['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'Aa', 'A', 'A', 'A', 'A', 'A', 'A', 'A']
# your bill without discount is 1600 with discount 1440.0

# %% [markdown]
# 12) A school has following rules for grading system:
#
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 50 - D
#
# d. 50 to 60 - C
#
# e. 60 to 80 - B
#
# f. Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
x = int(input("enter the marks of student to cheack grade"))
if x <= 100:
    match x:
        case x if 80 < x <= 100:
            print("grade is A")
        case x if 60 < x <= 80:
            print("grade is B")
        case x if 50 < x <= 60:
            print("grade is C")
        case x if 45 < x <= 50:
            print("grade is D")
        case x if 25 < x <= 45:
            print("grade is E")            
        case _:
            print("grade is F")    
else:
    print("please enter the gradeable marks")
# Out:
# grade is A

# %% [markdown]
# 14)A student will not be allowed to sit in exam if his/her attendence is less than 75%.
#
# Take following input from user
#
# - Number of classes held
#
# - Number of classes attended.
#
# And print
#
# - percentage of class attended
#
# - Is student is allowed to sit in exam or not.

# %%
total_class_attended = int(input("Enter the student's attendence"))
print(" the no of classes attended by student", total_class_attended )
total_class_held = int(input("Enter the total classes held by institute"))
print("the no of classes held by institute",total_class_held)

percentage = (total_class_attended/total_class_held) * 100

if percentage > 75:
    print(f"you are allowed to attend the exam your attendence is {percentage}% ")
else:
    print("you are not elligible to enter in exam room")
# Out:
#  the no of classes attended by student 45
# the no of classes held by institute 65
# you are not elligible to enter in exam room

# %% [markdown]
# 15) Modify the above question to allow student to sit if he/she has medical cause. Ask user if he/she has medical cause or not ( 'Y' or 'N' ) and print accordingly.

# %%
total_class_attended = int(input("Enter the student's attendence"))
print(" the no of classes attended by student", total_class_attended )
total_class_held = int(input("Enter the total classes held by institute"))
print("the no of classes held by institute",total_class_held)

percentage = (total_class_attended/total_class_held) * 100
cerificae = input("so u have madical certificate of illness").lower()
if  percentage > 75:
    print(f"you are allowed to attend the exam your attendence is {percentage}% ")
elif  percentage < 75 and cerificae == "yes"  :
    print(f"you are allowed to attend the exam your attendence is {percentage}% low but you have medicle certificate")
else:
    print("you are not elligible to enter in exam room")
# Out:
#  the no of classes attended by student 45
# the no of classes held by institute 100
# you are allowed to attend the exam your attendence is 45.0% low but you have medicle certificate

# %% [markdown]
# 16) Write a program to check if a year is leap year or not.
#
# If a year is divisible by 4 then it is leap year but if the year is century year like 2000, 1900, 2100 then it must be divisible by 400.

# %%
year = int(input("Enter a year: "))


if year % 100 == 0:
    print("This is a Century Year.")
    
    
    if year % 400 == 0:
        print("And it is also a Leap Year.")
    else:
        print("But it is NOT a Leap Year.")
else:
    print("This is NOT a Century Year.")
    
    
    if year % 4 == 0:
        print("It is a Leap Year.")
    else:
        print("It is NOT a Leap Year.")
# Out:
# This is a Century Year.
# But it is NOT a Leap Year.

# %% [markdown]
# 17) Ask user to enter age, gender ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
#
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR"

# %%
age = int(input(" Enter the age of employee"))
gender = input(" Enter the gender of empoyee").lower()
marital_status = input("Enter marital staus of employee").lower()

match (age, gender, marital_status):
    case  (_,"female",_):
        print("your working area is urban city")
    case (age,"male",_) if 20 <= age <= 40:
        print("you can do job anywhere")     
    case (age,"male",_) if 40 <= age <= 60:
        print("your working area is urban city")    
    case (age,_,_) if  age > 60  and age < 20:
        print("Error you entered wrong age")
    case (_,_,_):
        print("please enter correct data")
# Out:
# please enter correct data

# %% [markdown]
# 6) Write a program to calculate the electricity bill (accept number of unit from user) according to the following criteria :
#      Unit                                                     Price
# uptp 100 units                                             no charge
# Next 200 units                                              Rs 5 per unit
# After 200 units                                             Rs 10 per unit
# (For example if input unit is 350 than total bill amount is Rs.3500
# (For example if input unit is 97 than total bill amount is Rs.0
# (For example if input unit is 150 than total bill amount is Rs.750

# %%
def bill():
    units = int(input("Enter the number of units"))
    match units:
        case units if 100 < units <=200:
            print(f"total amount to pay is { units * 5} and your units are {units}")
        case units if units > 200: 
            print(f"total amount to pay is { units * 10} and your units are {units}")
        case _:
            print(f"your bill is zero and your units are {units}")

bill()
# Out:
# your bill is zero and your units are 20

# %% [markdown]
# 13) Take input of age of 3 people by user and determine oldest and youngest among them.

# %%
def age_comparison(): 
    print("Enter the age of three persons")
    age = []
    
    for n in range(1,4):
        
        n = int(input(f"Enetr the age of person {n}"))
        age.append(n)
    print(f"your entered ages of three persons are : {age}")  
    oldest_one = max(age[0],age[1],age[2])
    
    youngest_one = min(age[0],age[1],age[2])
    
    age.remove(oldest_one)
    age.remove(youngest_one)
    print(f"most aged is {oldest_one} years old , youngest one is {youngest_one} years old and middle aged person is {age[-1]} years old  ")
age_comparison()
# Out:
# Enter the age of three persons
# your entered ages of three persons are : [32, 34, 36]
# most aged is 36 years old , youngest one is 32 years old and middle aged person is 34 years old
